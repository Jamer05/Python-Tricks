# %%
#Program starts
#input data session below
title ='''
 _____ _ _       _     _     ____        _
|  ___| (_) __ _| |__ | |_  |  _ \  __ _| |_ __ _
| |_  | | |/ _` | '_ \| __| | | | |/ _` | __/ _` |
|  _| | | | (_| | | | | |_  | |_| | (_| | || (_| |
|_|   |_|_|\__, |_| |_|\__| |____/ \__,_|\__\__,_|
           |___/
           '''
print(title)
flight_id = int(input("Enter Flight Id: "))
print("============================================")
airline = input("Enter Airline: ")
print("============================================")
departure = input("Enter Departure: ")
print("============================================")
aircraft_type= input("Enter Aicraft Type: ")
print("============================================")
status = input("Enter Status: ")
print("============================================")


#end of input data
#Display Fligh data


print("\n\n=====================Flight Details=======================")
output=f'''

Flight ID: {flight_id}

Airline: {airline}

Departing to: {departure}

Status: {status}

Remark: {departure_time}

Aircraft Type: {aircraft_type}


'''
print(output)
print("============================================")
# Out:
#  _____ _ _       _     _     ____        _
# |  ___| (_) __ _| |__ | |_  |  _ \  __ _| |_ __ _
# | |_  | | |/ _` | '_ \| __| | | | |/ _` | __/ _` |
# |  _| | | | (_| | | | | |_  | |_| | (_| | || (_| |
# |_|   |_|_|\__, |_| |_|\__| |____/ \__,_|\__\__,_|
#            |___/
#
# Enter Flight Id: 23
# ...
# Enter Airline: asd
# ...
# Enter Departure: sasa
# ...
# Enter Aicraft Type: dsas
# ...
# Enter Status: dsd
# ...
#
#
# =====================Flight Details=======================
#
#
# Flight ID: 23
#
# Airline: asd
#
# Departing to: sasa
#
# Status: dsd
#
# Remark: 232
#
# Aircraft Type: dsas
#
#
#
# ...
